# %%
import pandas as pd

# Load Dataset
df = pd.read_csv('Dataset/Superstore.csv', encoding='latin1')

# Preview data
df.head()
# Out:
#                          Category       City  Container  Customer ID  \
# 0                           Paper    Lombard  Small Box         3035
# 1                           Paper    Lombard   Wrap Bag         3035
# 2             Pens & Art Supplies  Southbury   Wrap Bag         3385
# 3  Binders and Binder Accessories  Coachella  Small Box         3133
# 4                    Rubber Bands  Coachella   Wrap Bag         3133
#
#         Customer Name Customer Segment       Department  Item ID  \
# 0         Mark Bailey      Home Office  Office Supplies    10074
# 1         Mark Bailey      Home Office  Office Supplies    10079
# 2     Daniel Richmond        Corporate  Office Supplies    11012
# 3  Kristine Singleton        Corporate  Office Supplies    10646
# 4  Kristine Singleton        Corporate  Office Supplies    10138
#
#                                                 Item  Order Date  ...  \
# 0  Hammermill CopyPlus Copy Paper (20Lb. and 84 B...   11/8/2016  ...
# ...

# %%
#Data Inspection
#check datatypes

#check column types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Category             9426 non-null   object
#  1   City                 9426 non-null   object
#  2   Container            9426 non-null   object
#  3   Customer ID          9426 non-null   int64
#  4   Customer Name        9426 non-null   object
#  5   Customer Segment     9426 non-null   object
#  6   Department           9426 non-null   object
#  7   Item ID              9426 non-null   int64
#  8   Item                 9426 non-null   object
#  9   Order Date           9426 non-null   object
#  10  Order ID             9426 non-null   int64
#  11  Order Priority       9426 non-null   object
#  12  Postal Code          9426 non-null   int64
#  13  Region               9426 non-null   object
#  14  Row ID               9426 non-null   object
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Category               0
# City                   0
# Container              0
# Customer ID            0
# Customer Name          0
# Customer Segment       0
# Department             0
# Item ID                0
# Item                   0
# Order Date             0
# Order ID               0
# Order Priority         0
# Postal Code            0
# Region                 0
# Row ID                 0
# Ship Date              0
# Ship Mode              0
# State                  0
# Discount               0
# Order Quantity         0
# Product Base Margin    0
# Profit                 0
# Sales                  0
# Shipping Cost          0
# Unit Price             0
# dtype: int64

# %%
#Summary Statistics for numerical columns
df.describe()
# Out:
#        Customer ID       Item ID      Order ID   Postal Code     Discount  \
# count  9426.000000   9426.000000   9426.000000   9426.000000  9426.000000
# mean   1738.422236  10734.269998  82318.489073  47136.702313     0.049628
# std     979.167197    340.712162  19149.448857  32079.511571     0.031798
# min       2.000000  10001.000000      6.000000   1001.000000     0.000000
# 25%     898.000000  10470.000000  86737.250000  18040.000000     0.020000
# 50%    1750.000000  10767.500000  88344.500000  46322.000000     0.050000
# 75%    2578.750000  11027.000000  89987.750000  76037.000000     0.080000
# max    3403.000000  11263.000000  91591.000000  99362.000000     0.250000
#
#        Order Quantity  Product Base Margin        Profit          Sales  \
# count     9426.000000          9426.000000   9426.000000    9426.000000
# mean        13.798430             0.508277    139.233503     949.716423
# std         15.107688             0.141901    998.486307    2598.020092
# ...

# %%
#Unique Values in 'Category' and 'Department'
print("Categories:",df['Category'].unique())
print("Departments:",df['Department'].unique())

#unique values in products
print('Items:',df ['Item'].unique()[:10])
# Out:
# Categories: ['Paper' 'Pens & Art Supplies' 'Binders and Binder Accessories'
#  'Rubber Bands' 'Storage & Organization' 'Tables' 'Office Furnishings'
#  'Telephones and Communication' 'Labels' 'Appliances' 'Envelopes'
#  'Computer Peripherals' 'Chairs & Chairmats' 'Office Machines' 'Bookcases'
#  'Scissors, Rulers and Trimmers' 'Copiers and Fax']
# Departments: ['Office Supplies' 'Furniture' 'Technology']
# Items: ['Hammermill CopyPlus Copy Paper (20Lb. and 84 Bright)'
#  'Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"'
#  'Premium Writing Pencils, Soft, #2 by Central Association for the Blind'
#  'Fellowes Black Plastic Comb Bindings' 'Assorted Color Push Pins'
#  'Fellowes Personal Hanging Folder Files, Navy'
#  'Bevis Round Conference Table Top, X-Base'
#  'Rubbermaid ClusterMat Chairmats, Mat Size- 66" x 60", Lip 20" x 11" -90 Degree Angle'
#  'TOPS Money Receipt Book, Consecutively Numbered in Red,'
#  'Stockwell Push Pins']

# %%
df.columns=df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['Category', 'City', 'Container', 'Customer ID', 'Customer Name', 'Customer Segment', 'Department', 'Item ID', 'Item', 'Order Date', 'Order ID', 'Order Priority', 'Postal Code', 'Region', 'Row ID', 'Ship Date', 'Ship Mode', 'State', 'Discount', 'Order Quantity', 'Product Base Margin', 'Profit', 'Sales', 'Shipping Cost', 'Unit Price']

# %%
import matplotlib.pyplot as plt

df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar', figsize=(10,6))
plt.title("Top 10 States by Sales")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('Category')['Profit'].sum().plot(kind='bar', color='skyblue')
plt.title("Profit by Category")
plt.ylabel("Total Profit")
plt.xticks(rotation=0)
plt.show()
